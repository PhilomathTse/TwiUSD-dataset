# %%
import csv
with open('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/test.csv', mode='r', encoding='utf-8') as file_test:
    csv_reader = csv.DictReader(file_test)
    user_json = {}
    for row in csv_reader:
# Out:
# 65082850
# 31245195
# 1003662615661436929
# 1007003860408373248
# 403771846
# 1216167347943329792
# 1382431445063495688
# 1239013834741989376
# 838095416663162880
# 1481513318363787267
# 58882633
# 1221832590094753793
# 24403188
# 32562983
# 1461814120249008137
# 27864689
# 14356116
# 1480291462285873157
# 731634276903624705
# 2423855490
# 160720376
# 15007149
# 930312537958174720
# 953719157178036224
# 825829081866436608
# 1004804740105035777
# 1380403600699064322
# 1133463477656457216
# 222180430
# 283755001
# 850043038177120256
# 531563448
# 833745288
# 40072360
# 856559934967869441
# 732180604406534144
# 22827784
# 961214442
# 313410120
# 857497469348794368
# 1260337045022498816
# 1353711003628920832
# 928153625930612736
# 804218683413426177
# 561339107
# 16062453
# 1322320623943692290
# 879244261
# 2976976116
# 1278862379263148032
# 998573295044874241
# 1243915899561746434
# 2261210518
# 1271568481012588547
# 716688050
# 189009947
# 1462866467674894337
# 930566035
# ...

# %%
import json
file_followed_description = json.load(open("/home/niufuqiang/NFQ/Uset_SD/dataset copy/data/followed_user_description", encoding='utf-8'))

dict_followed_description = {}
for i in file_followed_description:
    dict_followed_description[i] = file_followed_description[i]

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/test.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if pd.isna(csv_reader.at[i, 'description']):
        if id in dict_followed_description:
            csv_reader['description'][i] = dict_followed_description[id]
            num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/test_add_followed_description.csv', index=False, encoding='utf-8')
# Out:
# 16
# /tmp/ipykernel_1304667/2000063223.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_1304667/2000063223.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_1304667/2000063223.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/train.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if pd.isna(csv_reader.at[i, 'description']):
        if id in dict_followed_description:
            csv_reader['description'][i] = dict_followed_description[id]
            num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/train_add_followed_description.csv', index=False, encoding='utf-8')
# Out:
# /tmp/ipykernel_2299946/4148768628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_2299946/4148768628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_2299946/4148768628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/valid.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if pd.isna(csv_reader.at[i, 'description']):
        if id in dict_followed_description:
            csv_reader['description'][i] = dict_followed_description[id]
            num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/valid_add_followed_description.csv', index=False, encoding='utf-8')
# Out:
# 547
# /tmp/ipykernel_1304667/1006966166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_1304667/1006966166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_1304667/1006966166.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/trump/test.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if pd.isna(csv_reader.at[i, 'description']):
        if id in dict_followed_description:
            csv_reader['description'][i] = dict_followed_description[id]
            num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/trump/test_add_followed_description.csv', index=False, encoding='utf-8')
# Out:
# 564
# /tmp/ipykernel_1304667/4203760988.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_1304667/4203760988.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_1304667/4203760988.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/trump/train.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if pd.isna(csv_reader.at[i, 'description']):
        if id in dict_followed_description:
            csv_reader['description'][i] = dict_followed_description[id]
            num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/trump/train_add_followed_description.csv', index=False, encoding='utf-8')
# Out:
# /tmp/ipykernel_1304667/2060879248.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_1304667/2060879248.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_1304667/2060879248.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/trump/valid.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if pd.isna(csv_reader.at[i, 'description']):
        if id in dict_followed_description:
            csv_reader['description'][i] = dict_followed_description[id]
            num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/trump/valid_add_followed_description.csv', index=False, encoding='utf-8')
# Out:
# 559
# /tmp/ipykernel_1304667/2217997184.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_1304667/2217997184.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['description'][i] = dict_followed_description[id]
# /tmp/ipykernel_1304667/2217997184.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import json
file_followed_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/dataset copy/data/followed_user_tweet_score", encoding='utf-8'))

dict_followed_tweet = {}
for i in file_followed_tweet:
    dict_followed_tweet[i] = file_followed_tweet[i]

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/test_add_followed_description.csv', encoding='utf-8')
csv_reader['followed_tweet'] = 'default_value'
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if id in dict_followed_tweet:
        csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
        num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/test_add_followed_description.csv', index=False, encoding='utf-8')
# Out:
# 888
# /tmp/ipykernel_2299946/2427459347.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
# /tmp/ipykernel_2299946/2427459347.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
# /tmp/ipykernel_2299946/2427459347.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/train_add_followed_description.csv', encoding='utf-8')
csv_reader['followed_tweet'] = 'default_value'
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if id in dict_followed_tweet:
        csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
        num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/train_add_followed_description.csv', index=False, encoding='utf-8')
# Out:
# /tmp/ipykernel_2299946/1240987739.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
# /tmp/ipykernel_2299946/1240987739.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
# /tmp/ipykernel_2299946/1240987739.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/valid_add_followed_description.csv', encoding='utf-8')
csv_reader['followed_tweet'] = 'default_value'
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if id in dict_followed_tweet:
        csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
        num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/valid_add_followed_description.csv', index=False, encoding='utf-8')
# Out:
# 887
# /tmp/ipykernel_2299946/3898784326.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
# /tmp/ipykernel_2299946/3898784326.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
# /tmp/ipykernel_2299946/3898784326.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import json
file_followed_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/dataset_copy/data/trump_user_follow_tweet_score.json", encoding='utf-8'))

dict_followed_tweet = {}
for i in file_followed_tweet:
    dict_followed_tweet[i] = file_followed_tweet[i]

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/test_add_followed_description.csv', encoding='utf-8')
csv_reader['followed_tweet'] = 'default_value'
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if id in dict_followed_tweet:
        csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
        num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/test_add_followed_description.csv', index=False, encoding='utf-8')

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/train_add_followed_description.csv', encoding='utf-8')
csv_reader['followed_tweet'] = 'default_value'
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if id in dict_followed_tweet:
        csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
        num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/train_add_followed_description.csv', index=False, encoding='utf-8')

# %%
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/valid_add_followed_description.csv', encoding='utf-8')
csv_reader['followed_tweet'] = 'default_value'
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    if id in dict_followed_tweet:
        csv_reader['followed_tweet'][i] = dict_followed_tweet[id]
        num = num + 1
print(num)
csv_reader.to_csv('/home/niufuqiang/NFQ/Uset_SD/dataset copy/biden/valid_add_followed_description.csv', index=False, encoding='utf-8')
