# %%
# 统计Biden推文相关性比例
import json
file_tweet_score = json.load(open("/home/niufuqiang/NFQ/Uset_SD/dataset_copy/data/followed_user_tweet_score", encoding='utf-8'))
score_1 = 0
score_2 = 0
score_3 = 0
num = 0
for i in file_tweet_score:
    for key, value in file_tweet_score[i][0].items():
        score_1 = score_1 + len(value['1'])
        score_2 = score_2 + len(value['2'])
        score_3 = score_3 + len(value['3'])
num = score_1 + score_2 + score_3
print(num)
print("1:", score_1 / num)
print("2:", score_2 / num)
print("3:", score_3 / num)
# Out:
# 47369
# 1: 0.3264160104709831
# 2: 0.4031961831577614
# 3: 0.2703878063712555

# %%
# 统计Trump推文相关性比例
import json
file_tweet_score = json.load(open("/home/niufuqiang/NFQ/Uset_SD/dataset_copy/data/trump_user_follow_tweet_score.json", encoding='utf-8'))
score_1 = 0
score_2 = 0
score_3 = 0
num = 0
for i in file_tweet_score:
    for key, value in file_tweet_score[i][0].items():
        score_1 = score_1 + len(value['1'])
        score_2 = score_2 + len(value['2'])
        score_3 = score_3 + len(value['3'])
num = score_1 + score_2 + score_3
print(num)
print("1:", score_1 / num)
print("2:", score_2 / num)
print("3:", score_3 / num)

# %%
# 统计Biden test.csv没有description的比例
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/test.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 60
# 0.04065040650406504

# %%
# 统计Biden train.csv没有description的比例
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/train.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 254
# 0.050316957210776544

# %%
# 统计Biden valid.csv没有description的比例
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/valid.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 65
# 0.045327754532775454

# %%
# 统计Trump test.csv没有description的比例
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/test.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 15
# 0.008695652173913044

# %%
# 统计Trump train.csv没有description的比例
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/train.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 35
# 0.005514416259650229

# %%
# 统计Trump valid.csv没有description的比例
import csv
import pandas as pd
import numpy as np
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/valid.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 15
# 0.008726003490401396

# %%
# 统计Biden test.csv description平均长度
import csv
import pandas as pd
import numpy as np
num = 0
a = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/test.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    num = num + 1
    a = a + len(csv_reader.at[i, 'description'])
print(num)
print(a / num)
# Out:
# 1416
# 117.04237288135593

# %%
# 统计Biden train.csv description平均长度
import csv
import pandas as pd
import numpy as np
num = 0
a = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/train.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    num = num + 1
    a = a + len(csv_reader.at[i, 'description'])
print(num)
print(a / num)
# Out:
# 4794
# 117.84334584897789

# %%
# 统计Biden valid.csv description平均长度
import csv
import pandas as pd
import numpy as np
num = 0
a = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/valid.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    num = num + 1
    a = a + len(csv_reader.at[i, 'description'])
print(num)
print(a / num)
# Out:
# 1369
# 119.42147552958363

# %%
# 统计Trump test.csv description平均长度
import csv
import pandas as pd
import numpy as np
num = 0
a = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/test.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    num = num + 1
    a = a + len(csv_reader.at[i, 'description'])
print(num)
print(a / num)
# Out:
# 1710
# 111.93918128654971

# %%
# 统计Trump train.csv description平均长度
import csv
import pandas as pd
import numpy as np
num = 0
a = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/train.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    num = num + 1
    a = a + len(csv_reader.at[i, 'description'])
print(num)
print(a / num)
# Out:
# 6312
# 113.44264892268694

# %%
# 统计Trump valid.csv description平均长度
import csv
import pandas as pd
import numpy as np
num = 0
a = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/valid.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    num = num + 1
    a = a + len(csv_reader.at[i, 'description'])
print(num)
print(a / num)
# Out:
# 1704
# 114.9430751173709

# %%
# 统计Biden被关注用户推文数量
import json
file_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/data/数据/followed/biden/tweet-manner/comment.json", encoding = 'utf-8'))
dict_tweet_len = {}
num = 0
for i in file_tweet:
    tweet_id = i
    dict_tweet_len[tweet_id] = len(file_tweet[i]['body'])
    num = num + len(file_tweet[i]['body'])
print("推文总数量", len(dict_tweet_len))
print("推文平均长度", num / len(dict_tweet_len))
# Out:
# 推文总数量 4782
# 推文平均长度 164.965495608532

# %%
# 统计Biden单个用户平均推文数量、立场比例
import json
file_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/data/数据/followed/biden/tweet-manner/post.json", encoding = 'utf-8'))
against = 0
none = 0
favor = 0
num = 4782
for i in file_tweet:
    if file_tweet[i]['manner'] == 'against':
        against = against + 1
    elif file_tweet[i]['manner'] == 'none':
        none = none + 1
    else:
        favor = favor + 1
print("against:", against, against / len(file_tweet))
print("none", none, none / len(file_tweet))
print("favor", favor, favor / len(file_tweet))
print("用户平均推文数量", num / len(file_tweet))
# Out:
# against: 156 0.16115702479338842
# none 338 0.34917355371900827
# favor 474 0.4896694214876033
# 用户平均推文数量 4.940082644628099

# %%
# 统计Trump被关注用户推文数量
import json
file_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/data/数据/followed/trump/tweet-manner/comment.json", encoding = 'utf-8'))
dict_tweet_len = {}
num = 0
for i in file_tweet:
    tweet_id = i
    dict_tweet_len[tweet_id] = len(file_tweet[i]['body'])
    num = num + len(file_tweet[i]['body'])
print("推文总数量", len(dict_tweet_len))
print("推文平均长度", num / len(dict_tweet_len))
# Out:
# 推文总数量 7854
# 推文平均长度 146.89674051438757

# %%
# 统计Trump单个用户平均推文数量、立场比例
import json
file_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/data/数据/followed/trump/tweet-manner/post.json", encoding = 'utf-8'))
against = 0
none = 0
favor = 0
num = 4782
for i in file_tweet:
    if file_tweet[i]['manner'] == 'against':
        against = against + 1
    elif file_tweet[i]['manner'] == 'none':
        none = none + 1
    else:
        favor = favor + 1
print("against:", against, against / len(file_tweet))
print("none", none, none / len(file_tweet))
print("favor", favor, favor / len(file_tweet))
print("用户平均推文数量", num / len(file_tweet))
# Out:
# against: 586 0.5645472061657033
# none 349 0.33622350674373797
# favor 103 0.09922928709055877
# 用户平均推文数量 4.606936416184971

# %%
# 统计Biden关注用户推文数量
import json
file_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/data/数据/follow/biden/tweet/follow.json", encoding = 'utf-8'))
num = 0
a = 0
against = 0
none = 0
favor = 0
for key, value in file_tweet:
    num = num + len(value['tweets'])
    for j in value['tweets']:
        a = a + len(j)
file_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/data/数据/follow/biden/tweet/follow_stance.json", encoding = 'utf-8'))
for i in file_tweet:
    if i['manner'] == 'against':
        against = against + 1
    elif i['manner'] == 'none':
        none = none + 1
    else:
        favor = favor + 1
print("推文总数量", num)
print("推文平均长度", a / num)
print("用户平均推文数量", num / len(file_tweet))
print("against:", against, against / len(file_tweet))
print("noen:", none, none / len(file_tweet))
print("favor", favor, favor / len(file_tweet))
# Out:
# 推文总数量 13462
# 推文平均长度 92.12041301441093
# 用户平均推文数量 2.2755240027045303
# against: 1204 0.2035158891142664
# noen: 1076 0.18187964841108858
# favor 3636 0.6146044624746451

# %%
# 统计Biden关注用户推文数量
import json
file_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/data/数据/follow/biden/tweet/follow.json", encoding = 'utf-8'))
num = 0
a = 0
against = 0
none = 0
favor = 0
for key, value in file_tweet:
    num = num + len(value['tweets'])
    for j in value['tweets']:
        a = a + len(j)
file_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/data/数据/follow/biden/tweet/follow_stance.json", encoding = 'utf-8'))
for i in file_tweet:
    if i['manner'] == 'against':
        against = against + 1
    elif i['manner'] == 'none':
        none = none + 1
    else:
        favor = favor + 1
print("推文总数量", num)
print("推文平均长度", a / num)
print("用户平均推文数量", num / len(file_tweet))
print("against:", against, against / len(file_tweet))
print("noen:", none, none / len(file_tweet))
print("favor", favor, favor / len(file_tweet))

# %%
# 统计Trump关注用户推文数量
import json
file_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/data/数据/follow/trump/tweet/follow_stance.json", encoding = 'utf-8'))
num = 0
a = 0
against = 0
none = 0
favor = 0
for i in file_tweet:
    num = num + len(i['tweets'])
    for j in i['tweets']:
        a = a + len(j)
    if i['manner'] == 'against':
        against = against + 1
    elif i['manner'] == 'none':
        none = none + 1
    else:
        favor = favor + 1
print("推文总数量", num)
print("推文平均长度", a / num)
print("用户平均推文数量", num / len(file_tweet))
print("against:", against, against / len(file_tweet))
print("noen:", none, none / len(file_tweet))
print("favor", favor, favor / len(file_tweet))
# Out:
# 推文总数量 16746
# 推文平均长度 87.69395676579482
# 用户平均推文数量 2.807376362112322
# against: 5242 0.8787929589270747
# noen: 149 0.024979044425817266
# favor 574 0.09622799664710813

# %%
# 统计Trump用户推文数量
import json
file_tweet = json.load(open("/home/niufuqiang/NFQ/Uset_SD/data/数据/trump/tweet/follow_stance.json", encoding = 'utf-8'))
num = 0
a = 0
against = 0
none = 0
favor = 0
for i in file_tweet:
    num = num + len(i['tweets'])
    for j in i['tweets']:
        a = a + len(j)
    if i['manner'] == 'against':
        against = against + 1
    elif i['manner'] == 'none':
        none = none + 1
    else:
        favor = favor + 1
print("推文总数量", num)
print("推文平均长度", a / num)
print("用户平均推文数量", num / len(file_tweet))
print("against:", against, against / len(file_tweet))
print("noen:", none, none / len(file_tweet))
print("favor", favor, favor / len(file_tweet))
# Out:
# 推文总数量 4913
# 推文平均长度 104.0860981070629
# 用户平均推文数量 2.114027538726334
# against: 261 0.11230636833046471
# noen: 1194 0.5137693631669535
# favor 869 0.37392426850258176

# %%
# # 统计description中的hashtag
# import json
# set_hashtag = set()
# file_hashtag = json.load(open("/home/niufuqiang/NFQ/Uset_SD/dataset_copy/data/hashtag.json"))
# for i in file_hashtag:
#     set_hashtag.add(i['tag_name'])
# print(len(set_hashtag))

# %%
# 统计Biden test.csv description中hashtag的数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/test.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_hashtag)) + r')\b')
hashtag_user = []
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    matches = pattern.findall(csv_reader.at[i, 'description'], re.IGNORECASE)
    if matches:
        hashtag_user.append(csv_reader['id'][i])
        num = num + len(matches)
print(len(hashtag_user))
print(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       6 num = 0
#       7 csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/test.csv', encoding='utf-8')
# ----> 8 pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_hashtag)) + r')\b')
#       9 hashtag_user = []
#      10 for i in range(len(csv_reader)):
#
# NameError: name 'set_hashtag' is not defined

# %%
# 统计Biden train.csv description中hashtag的数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/train.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_hashtag)) + r')\b')
hashtag_user = []   
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    matches = pattern.findall(csv_reader.at[i, 'description'], re.IGNORECASE)
    if matches:
        hashtag_user.append(csv_reader['id'][i])
        num = num + len(matches)
print(len(hashtag_user))
print(num)
# Out:
# 4742
# 70277

# %%
# 统计Biden valid.csv description中hashtag的数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/valid.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_hashtag)) + r')\b')
hashtag_user = []   
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    matches = pattern.findall(csv_reader.at[i, 'description'], re.IGNORECASE)
    if matches:
        hashtag_user.append(csv_reader['id'][i])
        num = num + len(matches)
print(len(hashtag_user))
print(num)
# Out:
# 1349
# 20449

# %%
# 统计Trump test.csv description中hashtag的数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/test.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_hashtag)) + r')\b')
hashtag_user = []
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    matches = pattern.findall(csv_reader.at[i, 'description'], re.IGNORECASE)
    if matches:
        hashtag_user.append(csv_reader['id'][i])
        num = num + len(matches)
print(len(hashtag_user))
print(num)
# Out:
# 1681
# 24438

# %%
# 统计Trump train.csv description中hashtag的数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/train.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_hashtag)) + r')\b')
hashtag_user = []     
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    matches = pattern.findall(csv_reader.at[i, 'description'], re.IGNORECASE)
    if matches:
        hashtag_user.append(csv_reader['id'][i])
        num = num + len(matches)
print(len(hashtag_user))
print(num)
# Out:
# 6202
# 90434

# %%
# 统计Trump valid.csv description中hashtag的数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/valid.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_hashtag)) + r')\b')
hashtag_user = []     
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    matches = pattern.findall(csv_reader.at[i, 'description'], re.IGNORECASE)
    if matches:
        hashtag_user.append(csv_reader['id'][i])
        num = num + len(matches)
print(len(hashtag_user))
print(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       6 num = 0
#       7 csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/valid.csv', encoding='utf-8')
# ----> 8 pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_hashtag)) + r')\b')
#       9 hashtag_user = []
#      10 for i in range(len(csv_reader)):
#
# NameError: name 'set_hashtag' is not defined

# %%
# # 统计Biden test.csv description中@的比例
# import csv
# import pandas as pd
# import numpy as np
# import re
# num = 0
# set_at = set()
# set_at.add("@")
# csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/test.csv', encoding='utf-8')
# pattern = rf"\b{re.escape('@')}\b"
# at_user = []  
# for i in range(len(csv_reader)):
#     if pd.isna(csv_reader.at[i, 'description']):
#         continue
#     if re.search('@', csv_reader.at[i, 'description'],flags=re.I):
#     # matches = re.findall(rf"\b{'@'}\b", csv_reader.at[i, 'description'], re.IGNORECASE) 
#     # matches = re.findall(pattern, csv_reader.at[i, 'description'], re.IGNORECASE)
#     # if matches:
#         at_user.append(csv_reader['id'][i])
#         # num = num + len(matches)
# print(len(at_user))
# print(len(csv_reader))
# Out:
# 466
# 1476

# %%
# 统计Biden test.csv description中@的比例
import csv
import pandas as pd
import numpy as np
import re
num = 0
a = 0
set_at = set()
set_at.add('@')
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/test.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_at)) + r')\b')
at_user = set()
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    for j in range(len(csv_reader.at[i, 'description'])):
        if csv_reader.at[i, 'description'][j] == '@':
            a = a + 1
            at_user.add(csv_reader['id'][i])
print(len(at_user))
print(a)
# Out:
# 466
# 1060

# %%
# 统计Biden train.csv description中@的比例
import csv
import pandas as pd
import numpy as np
import re
num = 0
a = 0
set_at = set()
set_at.add('@')
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/train.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_at)) + r')\b')
at_user = set()
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    for j in range(len(csv_reader.at[i, 'description'])):
        if csv_reader.at[i, 'description'][j] == '@':
            a = a + 1
            at_user.add(csv_reader['id'][i])
print(len(at_user))
print(a)
# Out:
# 1528
# 3580

# %%
# 统计Biden valid.csv description中@的比例
import csv
import pandas as pd
import numpy as np
import re
num = 0
a = 0
set_at = set()
set_at.add('@')
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/valid.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_at)) + r')\b')
at_user = set()
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    for j in range(len(csv_reader.at[i, 'description'])):
        if csv_reader.at[i, 'description'][j] == '@':
            a = a + 1
            at_user.add(csv_reader['id'][i])
print(len(at_user))
print(a)
# Out:
# 510
# 1112

# %%
# 统计Trump test.csv description中@的比例
import csv
import pandas as pd
import numpy as np
import re
num = 0
a = 0
set_at = set()
set_at.add('@')
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/test.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_at)) + r')\b')
at_user = set()
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    for j in range(len(csv_reader.at[i, 'description'])):
        if csv_reader.at[i, 'description'][j] == '@':
            a = a + 1
            at_user.add(csv_reader['id'][i])
print(len(at_user))
print(a)
# Out:
# 496
# 1031

# %%
# 统计Trump train.csv description中@的比例
import csv
import pandas as pd
import numpy as np
import re
num = 0
a = 0
set_at = set()
set_at.add('@')
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/train.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_at)) + r')\b')
at_user = set()
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    for j in range(len(csv_reader.at[i, 'description'])):
        if csv_reader.at[i, 'description'][j] == '@':
            a = a + 1
            at_user.add(csv_reader['id'][i])
print(len(at_user))
print(a)
# Out:
# 1729
# 3745

# %%
# 统计Trump valid.csv description中@的比例
import csv
import pandas as pd
import numpy as np
import re
num = 0
a = 0
set_at = set()
set_at.add('@')
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/valid.csv', encoding='utf-8')
pattern = re.compile(r'\b(' + '|'.join(map(re.escape, set_at)) + r')\b')
at_user = set()
for i in range(len(csv_reader)):
    if pd.isna(csv_reader.at[i, 'description']):
        continue
    for j in range(len(csv_reader.at[i, 'description'])):
        if csv_reader.at[i, 'description'][j] == '@':
            a = a + 1
            at_user.add(csv_reader['id'][i])
print(len(at_user))
print(a)
# Out:
# 524
# 1125

# %%
# 统计Biden test.csv数据标注根据followed的用户数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/test.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if csv_reader['remark'][i] == 'according to followed':
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 164
# 0.1111111111111111

# %%
# 统计Biden train.csv数据标注根据followed的用户数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/train.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if csv_reader['remark'][i] == 'according to followed':
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 822
# 0.1628367670364501

# %%
# 统计Biden valid.csv数据标注根据followed的用户数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/valid.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if csv_reader['remark'][i] == 'according to followed':
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 166
# 0.11576011157601115

# %%
# 统计Trump test.csv数据标注根据followed的用户数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/test.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if csv_reader['remark'][i] == 'according to followed':
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 282
# 0.1634782608695652

# %%
# 统计Trump train.csv数据标注根据followed的用户数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/train.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if csv_reader['remark'][i] == 'according to followed':
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 1221
# 0.1923743500866551

# %%
# 统计Trump valid.csv数据标注根据followed的用户数量
import csv
import pandas as pd
import numpy as np
import re
num = 0
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/valid.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    if csv_reader['remark'][i] == 'according to followed':
        num = num + 1
print(num)
print(num / len(csv_reader))
# Out:
# 255
# 0.14834205933682373

# %%
# 统计Biden用户的真实态度
import csv
import pandas as pd
import numpy as np
import re
dict_user_stance = {}
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/test.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    dict_user_stance[id] = csv_reader['stance'][i]

# %%
# 统计Biden用户的真实态度
import csv
import pandas as pd
import numpy as np
import re
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/train.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    dict_user_stance[id] = csv_reader['stance'][i]

# %%
# 统计Biden用户的真实态度
import csv
import pandas as pd
import numpy as np
import re
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/biden/valid.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    dict_user_stance[id] = csv_reader['stance'][i]

# %%
import json
print(len(dict_user_stance))
with open('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/data/user_real_stance.json', 'w') as outfile:
    json.dump(dict_user_stance, outfile,indent=2,ensure_ascii=False)
    outfile.write("\n")
# Out:
# 6873

# %%
# 统计Trump用户的真实态度
import csv
import pandas as pd
import numpy as np
import re
dict_user_stance = {}
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/test.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    dict_user_stance[id] = csv_reader['stance'][i]

# %%
# 统计Trump用户的真实态度
import csv
import pandas as pd
import numpy as np
import re
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/train.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    dict_user_stance[id] = csv_reader['stance'][i]

# %%
# 统计Trump用户的真实态度
import csv
import pandas as pd
import numpy as np
import re
csv_reader = pd.read_csv('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/trump/valid.csv', encoding='utf-8')
for i in range(len(csv_reader)):
    id = str(csv_reader['id'][i])
    dict_user_stance[id] = csv_reader['stance'][i]

# %%
import json
print(len(dict_user_stance))
with open('/home/niufuqiang/NFQ/Uset_SD/dataset_copy/data/trump_user_real_stance.json', 'w') as outfile:
    json.dump(dict_user_stance, outfile,indent=2,ensure_ascii=False)
    outfile.write("\n")
# Out:
# 8731
